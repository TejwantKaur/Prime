# %%
1+1
# Out:
# 2

# %%
import json

# %%
def load_data(filenmae):
    with open(filename,"r") as f:
        data = json.load(f)

    return data

# %%
data = load_data("store_data.json");
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data = load_data("store_data.json");
#       2 print(data)
#
# Cell In[4], line 2, in load_data(filenmae)
#       1 def load_data(filenmae):
# ----> 2     with open(filename,"r") as f:
#       3         data = json.load(f)
#       5     return data
#
# NameError: name 'filename' is not defined
